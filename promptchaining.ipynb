# %%
pip install langchain langchain-community langchain-openai langgraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.31-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.35-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph
#   Downloading langgraph-0.6.11-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Downloading langchain_core-0.3.81-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.37-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.45-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3,>=2 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.3)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<1.0.0,>=0.3.72->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.5-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.25.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.12.0)
# Requirement already satisfied: certifi in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2.6.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.0.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.22.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (75 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Collecting openai<3.0.0,>=1.104.2 (from langchain-openai)
#   Downloading openai-2.14.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading jiter-0.12.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/yesh/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.11.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.7.0,>=0.6.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.6.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.6.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.11.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.2 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.8 MB/s  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.3.81-py3-none-any.whl (457 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading langsmith-0.4.37-py3-none-any.whl (396 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 33.6 MB/s  0:00:00
# Downloading sqlalchemy-2.0.45-cp39-cp39-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.5 MB/s  0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading langchain_community-0.3.31-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 39.0 MB/s  0:00:00
# Downloading aiohttp-3.13.3-cp39-cp39-macosx_11_0_arm64.whl (492 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.0-cp39-cp39-macosx_11_0_arm64.whl (44 kB)
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp39-cp39-macosx_11_0_arm64.whl (94 kB)
# Downloading langchain_openai-0.3.35-py3-none-any.whl (75 kB)
# Downloading openai-2.14.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.2 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (312 kB)
# Downloading tiktoken-0.12.0-cp39-cp39-macosx_11_0_arm64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.1/997.1 kB 30.1 MB/s  0:00:00
# Downloading langgraph-0.6.11-py3-none-any.whl (155 kB)
# Downloading langgraph_checkpoint-2.1.2-py3-none-any.whl (45 kB)
# Downloading langgraph_prebuilt-0.6.5-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading frozenlist-1.8.0-cp39-cp39-macosx_11_0_arm64.whl (50 kB)
# Downloading orjson-3.11.5-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (245 kB)
# Downloading ormsgpack-1.11.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (367 kB)
# Downloading propcache-0.4.1-cp39-cp39-macosx_11_0_arm64.whl (47 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading regex-2025.11.3-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.25.0-cp39-cp39-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.6/640.6 kB 23.0 MB/s  0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, typing-inspection, typing-inspect, tqdm, tenacity, SQLAlchemy, sniffio, regex, python-dotenv, pydantic-core, propcache, ormsgpack, orjson, multidict, marshmallow, jsonpatch, jiter, httpx-sse, frozenlist, distro, async-timeout, annotated-types, aiohappyeyeballs, yarl, tiktoken, requests-toolbelt, pydantic, dataclasses-json, aiosignal, pydantic-settings, aiohttp, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain-openai, langgraph-prebuilt, langchain, langgraph, langchain-community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43/43 [langchain-community]ommunity]ore]
# Successfully installed SQLAlchemy-2.0.45 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-types-0.7.0 async-timeout-4.0.3 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.8.0 httpx-sse-0.4.3 jiter-0.12.0 jsonpatch-1.33 langchain-0.3.27 langchain-community-0.3.31 langchain-core-0.3.81 langchain-openai-0.3.35 langchain-text-splitters-0.3.11 langgraph-0.6.11 langgraph-checkpoint-2.1.2 langgraph-prebuilt-0.6.5 langgraph-sdk-0.2.9 langsmith-0.4.37 marshmallow-3.26.2 multidict-6.7.0 openai-2.14.0 orjson-3.11.5 ormsgpack-1.11.0 propcache-0.4.1 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.11.0 python-dotenv-1.2.1 regex-2025.11.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 tiktoken-0.12.0 tqdm-4.67.1 typing-inspect-0.9.0 typing-inspection-0.4.2 xxhash-3.6.0 yarl-1.22.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# For better security, load environment variables from a .env file
# from dotenv import load dotenv
# Out:
# /Users/yesh/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# load_dotenv()
# Make sure your OPENAI_API_KEY is set in the .env file

# Initialize the Language Model (using ChatOpenAI is recommended)
llm = ChatOpenAI(temperature=0)

# --- Prompt 1: Extract Information ---
prompt_extract = ChatPromptTemplate.from_template(
    "Extract the technical specifications from the following text:\n\n{text_input}"
)

# --- Prompt 2: Transform to JSON ---
prompt_transform = ChatPromptTemplate.from_template(
    "Transform the following specifications into a JSON object with "
    "'cpu', 'memory', and 'storage' as keys:\n\n{specifications}"
)

# --- Build the Chain using LCEL ---
# The StrOutputParser() converts the LLM's message output to a simple string
extraction_chain = prompt_extract | llm | StrOutputParser()

# The full chain passes the output of the extraction chain into the
# 'specifications' variable for the transformation prompt.
full_chain = (
    {"specifications": extraction_chain}
    | prompt_transform
    | llm
    | StrOutputParser()
)

# --- Run the Chain ---
input_text = "The new laptop model features a 3.5 GHz octa-core processor, 16GB of RAM, and a 1TB NVMe SSD."

# Execute the chain with the input text dictionary.
final_result = full_chain.invoke({"text_input": input_text})

print("\n--- Final JSON Output ---")
print(final_result)
